# %% [markdown]
# <a href="https://colab.research.google.com/github/7atemAlawwad/T5/blob/main/Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import

df = pd.read_csv('/content/Task (1) Dataset.csv')

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# 2      Junior high school                Employee              1-2yr
# 3      Junior high school                Employee             5-10yr
# 4      Junior high school                Employee              2-5yr
# ...                   ...                     ...                ...
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#            Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0               Automobile            Owner              Above 10yr  ...
# 1      Public (> 45 seats)            Owner                 5-10yrs  ...
# 2          Lorry (41?100Q)            Owner                     NaN  ...
# 3      Public (> 45 seats)     Governmental                     NaN  ...
# 4                      NaN            Owner                 5-10yrs  ...
# ...                    ...              ...                     ...  ...
# 12311       Lorry (11?40Q)            Owner                     NaN  ...
# 12312           Automobile            Owner                     NaN  ...
# 12313                Bajaj            Owner                  2-5yrs  ...
# 12314      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 12315                Other            Owner                  2-5yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 0       Going straight               na              na                   na
# 1       Going straight               na              na                   na
# 2       Going straight  Driver or rider            Male                31-50
# 3       Going straight       Pedestrian          Female                18-30
# 4       Going straight               na              na                   na
# ...                ...              ...             ...                  ...
# 12311   Going straight               na              na                   na
# 12312            Other               na              na                   na
# 12313            Other  Driver or rider            Male                31-50
# 12314            Other               na              na                   na
# 12315         Stopping       Pedestrian          Female                    5
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 0                    na               NaN                  NaN
# 1                    na               NaN                  NaN
# 2                     3            Driver                  NaN
# 3                     3            Driver               Normal
# 4                    na               NaN                  NaN
# ...                 ...               ...                  ...
# 12311                na            Driver               Normal
# 12312                na            Driver               Normal
# 12313                 3            Driver               Normal
# 12314                na            Driver               Normal
# 12315                 3            Driver               Normal
#
#                                      Pedestrian_movement  \
# 0                                       Not a Pedestrian
# 1                                       Not a Pedestrian
# 2                                       Not a Pedestrian
# 3                                       Not a Pedestrian
# 4                                       Not a Pedestrian
# ...                                                  ...
# 12311                                   Not a Pedestrian
# 12312                                   Not a Pedestrian
# 12313                                   Not a Pedestrian
# 12314                                   Not a Pedestrian
# 12315  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident Accident_severity
# 0                           Moving Backward     Slight Injury
# 1                                Overtaking     Slight Injury
# 2                 Changing lane to the left    Serious Injury
# 3                Changing lane to the right     Slight Injury
# 4                                Overtaking     Slight Injury
# ...                                     ...               ...
# 12311                         No distancing     Slight Injury
# 12312                         No distancing     Slight Injury
# 12313            Changing lane to the right    Serious Injury
# 12314  Driving under the influence of drugs     Slight Injury
# 12315            Changing lane to the right     Slight Injury
#
# [12316 rows x 32 columns]

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
df['Driving_experience'] = df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])
df['Educational_level'] = df['Educational_level'].fillna(df['Educational_level'].mode()[0])
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0])
df['Service_year_of_vehicle'] = df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0])
df['Area_accident_occured'] = df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0])
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0])
df['Road_allignment'] = df['Road_allignment'].fillna(df['Road_allignment'].mode()[0])
df['Types_of_Junction'] = df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])
df['Road_surface_type'] = df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0])
df['Type_of_collision'] = df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0])
df['Work_of_casuality'] = df['Work_of_casuality'].fillna(df['Work_of_casuality'].mode()[0])
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0])
df['Defect_of_vehicle'] = df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode()[0])
df['Type_of_vehicle'] = df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])
df['Vehicle_movement'] = df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# Fitness_of_casuality           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df = df[df['Casualty_class'] != 'na']
df['Casualty_class'].unique()
# Out:
# ['Pedestrian', 'Passenger', 'Driver or rider']
# Categories (4, object): ['Driver or rider', 'Passenger', 'Pedestrian', 'na']

# %%
df = df[df['Sex_of_casualty'] != 'na']
df['Sex_of_casualty'].unique()
# Out:
# ['Male', 'Female']
# Categories (3, object): ['Female', 'Male', 'na']

# %%
df = df[df['Age_band_of_casualty'] != 'na']
df['Age_band_of_casualty'].unique()
# Out:
# ['Under 18', '18-30', '31-50', 'Over 51', '5']
# Categories (6, object): ['18-30', '31-50', '5', 'Over 51', 'Under 18', 'na']

# %%
df = df[df['Casualty_severity'] != 'na']
df['Casualty_severity'].unique()
# Out:
# ['3', '2', '1']
# Categories (4, object): ['1', '2', '3', 'na']

# %%
df = df[df['Service_year_of_vehicle'] != 'Unknown']
df['Service_year_of_vehicle'].unique()
# Out:
# ['1-2yr', '2-5yrs', '5-10yrs', 'Above 10yr', 'Below 1yr']
# Categories (5, object): ['1-2yr', '2-5yrs', '5-10yrs', 'Above 10yr', 'Below 1yr']

# %%
df
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 4     17:20:00      Friday              18-30          Male
# 5     17:20:00      Friday              18-30          Male
# 8     17:45:00    Thursday              31-50          Male
# 10     8:20:00     Tuesday              18-30          Male
# 11    15:10:00    Thursday              18-30          Male
# ...        ...         ...                ...           ...
# 4801  19:12:00     Tuesday              31-50          Male
# 4804   7:10:00      Friday              18-30          Male
# 4807   9:05:00      Friday              18-30          Male
# 4808  13:55:00      Sunday            Over 51          Male
# 4810  13:55:00      Sunday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 4     Junior high school                Employee         Above 10yr
# 5     Junior high school                Employee              1-2yr
# 8     Junior high school                Employee         Above 10yr
# 10    Junior high school                Employee          Below 1yr
# 11    Junior high school                Employee              2-5yr
# ...                  ...                     ...                ...
# 4801   Elementary school                   Owner         Above 10yr
# 4804  Junior high school                Employee              2-5yr
# 4807  Junior high school                Employee             5-10yr
# 4808  Junior high school                Employee             5-10yr
# 4810  Junior high school                Employee             5-10yr
#
#           Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 4         Lorry (41?100Q)            Owner                   1-2yr  ...
# 5              Automobile            Owner                  2-5yrs  ...
# 8              Automobile            Owner                   1-2yr  ...
# 10             Long lorry            Owner                 5-10yrs  ...
# 11         Lorry (11?40Q)            Owner                 5-10yrs  ...
# ...                   ...              ...                     ...  ...
# 4801      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 4804  Public (> 45 seats)            Owner                   1-2yr  ...
# 4807      Special vehicle            Owner              Above 10yr  ...
# 4808                Bajaj            Owner                  2-5yrs  ...
# 4810                Other            Owner                  2-5yrs  ...
#
#      Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 4      Going straight       Pedestrian            Male             Under 18
# 5              U-Turn        Passenger            Male                18-30
# 8      Going straight  Driver or rider          Female                18-30
# 10     Going straight  Driver or rider            Male             Under 18
# 11    Moving Backward  Driver or rider            Male                18-30
# ...               ...              ...             ...                  ...
# 4801   Going straight  Driver or rider          Female                31-50
# 4804  Moving Backward        Passenger            Male              Over 51
# 4807        Reversing        Passenger            Male              Over 51
# 4808            Other  Driver or rider            Male                31-50
# 4810         Stopping       Pedestrian          Female                    5
#
#      Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 4                    3            Driver               Normal
# 5                    3            Driver               Normal
# 8                    3            Driver               Normal
# 10                   3            Driver               Normal
# 11                   3            Driver               Normal
# ...                ...               ...                  ...
# 4801                 3            Driver               Normal
# 4804                 3            Driver               Normal
# 4807                 3          Employee               Normal
# 4808                 3            Driver               Normal
# 4810                 3            Driver               Normal
#
#                                     Pedestrian_movement  \
# 4                       Crossing from driver's nearside
# 5                                      Not a Pedestrian
# 8                                      Not a Pedestrian
# 10                                     Not a Pedestrian
# 11                                     Not a Pedestrian
# ...                                                 ...
# 4801                                   Not a Pedestrian
# 4804                                   Not a Pedestrian
# 4807                                   Not a Pedestrian
# 4808                                   Not a Pedestrian
# 4810  Crossing from nearside - masked by parked or s...
#
#                Cause_of_accident Accident_severity
# 4     Changing lane to the right     Slight Injury
# 5                Moving Backward    Serious Injury
# 8                  No distancing    Serious Injury
# 10               Moving Backward    Serious Injury
# 11                    Overtaking    Serious Injury
# ...                          ...               ...
# 4801                  Overtaking    Serious Injury
# 4804          Driving carelessly     Slight Injury
# 4807   Changing lane to the left    Serious Injury
# 4808  Changing lane to the right    Serious Injury
# 4810  Changing lane to the right     Slight Injury
#
# [3065 rows x 32 columns]

# %%
df = df[df['Age_band_of_driver'] != 'Unknown']
df['Age_band_of_driver'].unique()
# Out:
# array(['18-30', '31-50', 'Over 51', 'Under 18'], dtype=object)

# %%
df.dropna(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     17:02:00      Monday              18-30          Male
# 1     17:02:00      Monday              31-50          Male
# 2      1:06:00      Sunday              18-30          Male
# 3     17:20:00      Friday              18-30          Male
# 4     17:20:00      Friday              18-30          Male
# ...        ...         ...                ...           ...
# 4806  17:10:00      Friday              31-50          Male
# 4807   9:05:00      Friday              18-30          Male
# 4808  13:55:00      Sunday            Over 51          Male
# 4809  13:55:00      Sunday              18-30        Female
# 4810  13:55:00      Sunday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 0      Above high school                Employee              1-2yr
# 1     Junior high school                Employee         Above 10yr
# 2     Junior high school                Employee              2-5yr
# 3     Junior high school                Employee              2-5yr
# 4     Junior high school                Employee         Above 10yr
# ...                  ...                     ...                ...
# 4806  Junior high school                Employee         Above 10yr
# 4807  Junior high school                Employee             5-10yr
# 4808  Junior high school                Employee             5-10yr
# 4809  Junior high school                Employee         Above 10yr
# 4810  Junior high school                Employee             5-10yr
#
#           Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0              Automobile            Owner              Above 10yr  ...
# 1     Public (> 45 seats)            Owner                 5-10yrs  ...
# 2              Automobile            Owner                 5-10yrs  ...
# 3              Automobile     Governmental              Above 10yr  ...
# 4         Lorry (41?100Q)            Owner                   1-2yr  ...
# ...                   ...              ...                     ...  ...
# 4806     Pick up upto 10Q     Governmental               Below 1yr  ...
# 4807      Special vehicle            Owner              Above 10yr  ...
# 4808                Bajaj            Owner                  2-5yrs  ...
# 4809      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 4810                Other            Owner                  2-5yrs  ...
#
#      Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 0      Going straight               na              na                   na
# 1      Going straight               na              na                   na
# 2      Going straight               na              na                   na
# 3              U-Turn               na              na                   na
# 4      Going straight       Pedestrian            Male             Under 18
# ...               ...              ...             ...                  ...
# 4806  Moving Backward               na              na                   na
# 4807        Reversing        Passenger            Male              Over 51
# 4808            Other  Driver or rider            Male                31-50
# 4809            Other               na              na                   na
# 4810         Stopping       Pedestrian          Female                    5
#
#      Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 0                   na            Driver               Normal
# 1                   na            Driver               Normal
# 2                   na            Driver               Normal
# 3                   na            Driver               Normal
# 4                    3            Driver               Normal
# ...                ...               ...                  ...
# 4806                na            Driver               Normal
# 4807                 3          Employee               Normal
# 4808                 3            Driver               Normal
# 4809                na            Driver               Normal
# 4810                 3            Driver               Normal
#
#                                     Pedestrian_movement  \
# 0                                      Not a Pedestrian
# 1                                      Not a Pedestrian
# 2                                      Not a Pedestrian
# 3                                      Not a Pedestrian
# 4                       Crossing from driver's nearside
# ...                                                 ...
# 4806                                   Not a Pedestrian
# 4807                                   Not a Pedestrian
# 4808                                   Not a Pedestrian
# 4809                                   Not a Pedestrian
# 4810  Crossing from nearside - masked by parked or s...
#
#                          Cause_of_accident Accident_severity
# 0                          Moving Backward     Slight Injury
# 1                               Overtaking     Slight Injury
# 2                               Overtaking     Slight Injury
# 3                   No priority to vehicle     Slight Injury
# 4               Changing lane to the right     Slight Injury
# ...                                    ...               ...
# 4806                       Moving Backward     Slight Injury
# 4807             Changing lane to the left    Serious Injury
# 4808            Changing lane to the right    Serious Injury
# 4809  Driving under the influence of drugs     Slight Injury
# 4810            Changing lane to the right     Slight Injury
#
# [4811 rows x 32 columns]

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df['Day_of_week'] = df['Day_of_week'].astype('category')
df['Service_year_of_vehicle'] = df['Service_year_of_vehicle'].astype('category')
df['Number_of_vehicles_involved'] = df['Number_of_vehicles_involved'].astype('int64')
df['Number_of_casualties'] = df['Number_of_casualties'].astype('int64')
df['Defect_of_vehicle'] = df['Defect_of_vehicle'].astype('category')
df['Vehicle_movement'] = df['Vehicle_movement'].astype('category')
df['Cause_of_accident'] = df['Cause_of_accident'].astype('category')
df['Accident_severity'] = df['Accident_severity'].astype('category')
df['Casualty_class'] = df['Casualty_class'].astype('category')
df['Casualty_severity'] = df['Casualty_severity'].astype('category')
df['Sex_of_casualty'] = df['Sex_of_casualty'].astype('category')
df['Age_band_of_casualty'] = df['Age_band_of_casualty'].astype('category')
df['Work_of_casuality'] = df['Work_of_casuality'].astype('category')
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].astype('category')
df['Pedestrian_movement'] = df['Pedestrian_movement'].astype('category')
df['Driving_experience'] = df['Driving_experience'].astype('category')
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].astype('category')
df['Educational_level'] = df['Educational_level'].astype('category')
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].astype('category')
df['Type_of_vehicle'] = df['Type_of_vehicle'].astype('category')

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  4811.000000           4811.000000
# mean                      2.031386              1.574309
# std                       0.642284              1.016515
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       6.000000              7.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# Automobile              1647
# Lorry (41?100Q)          809
# Other                    473
# Pick up upto 10Q         338
# Stationwagen             285
# Public (12 seats)        263
# Lorry (11?40Q)           207
# Public (> 45 seats)      188
# Public (13?45 seats)     181
# Long lorry               149
# Taxi                     102
# Motorcycle                73
# Special vehicle           30
# Turbo                     21
# Ridden horse              20
# Bajaj                     15
# Bicycle                   10
# Name: count, dtype: int64

# %%
df['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Normal               3934
# Raining               554
# Other                 111
# Unknown                81
# Cloudy                 58
# Windy                  40
# Snow                   17
# Raining and Windy      13
# Fog or mist             3
# Name: count, dtype: int64

# %%
df['Area_accident_occured'].value_counts()
# Out:
# Area_accident_occured
# Other                   1590
# Office areas            1049
# Residential areas        965
#  Church areas            485
#  Industrial areas        207
# School areas             166
#  Outside rural areas     105
#  Hospital areas           91
#   Recreational areas      81
# Rural village areas       37
#   Market areas            34
# Recreational areas         1
# Name: count, dtype: int64

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age_band_of_driver'])
plt.title('Distribution of Age Band of Driver')
plt.xlabel('Age Band')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Type_of_vehicle', data=df)
plt.title('Distribution of Type of Vehicle')
plt.xlabel('Type of Vehicle')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
pd.crosstab(df['Age_band_of_driver'], df['Accident_severity'])
# Out:
# Accident_severity   Fatal injury  Serious Injury  Slight Injury
# Age_band_of_driver
# 18-30                         34             288           1604
# 31-50                         15             252           1554
# Over 51                       12              99            578
# Under 18                       5              65            305

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Accident_severity', data=df)
plt.title('Distribution of Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age_band_of_driver', y='Number_of_casualties', data=df)
plt.title('Relationship between Age Band of Driver and Number of Casualties')
plt.xlabel('Age Band of Driver')
plt.ylabel('Number of Casualties')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age_band_of_driver'])
plt.title('Distribution of Age Band of Driver')
plt.xlabel('Age Band')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Type_of_vehicle', data=df)
plt.title('Distribution of Type of Vehicle')
plt.xlabel('Type of Vehicle')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['Accident_severity'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Accident Severity')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age_band_of_driver', y='Number_of_casualties', data=df)
plt.title('Relationship between Age Band of Driver and Number of Casualties')
plt.xlabel('Age Band of Driver')
plt.ylabel('Number of Casualties')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(pd.crosstab(df['Age_band_of_driver'], df['Accident_severity']), annot=True)
plt.title('Relationship between Age Band of Driver and Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Age Band of Driver')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
#Most accidents are "Slight" severity
#Drivers aged 21-30 are most frequently involved in accidents
#Automobiles are the most common vehicle type in accidents
#There might be a correlation between older driver age and higher casualty numbers
#Younger drivers have more "Slight" accidents while older drivers have a higher proportion of "Serious" accidents
