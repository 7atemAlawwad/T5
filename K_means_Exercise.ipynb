# %% [markdown]
# <a href="https://colab.research.google.com/github/7atemAlawwad/T5/blob/main/K_means_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Step 1 : Import the necessary Libraries
# ### import iris dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

# %% [markdown]
# #Step 2 : Load the iris Dataset

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# #Step 3 : Elbow Method
# Finding the ideal number of groups to divide the data into is a basic stage in any unsupervised algorithm. One of the most common techniques for figuring out this ideal value of k is the elbow approach.

# %%
wcss = []


for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

# %% [markdown]
# #Step 4 : Plot the Elbow graph to find the optimum number of cluster

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, 11), wcss, marker='*', c = 'red')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %% [markdown]
# The plot displays a scatter plot of data points (X[:,0], X[:,1]) with grid lines. It also marks the initial cluster centers (red stars) generated for K-means clustering.

# %% [markdown]
# #Step 5 : Build the Kmeans clustering model
#
#
#
# *   Find the cluster center
# *   Predict the cluster group

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=42)
kmeans.fit(df)
df['Cluster'] = kmeans.labels_

# %% [markdown]
# #Step 6 : Predict the cluster group

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=df['Cluster'], cmap='viridis', marker='o')
plt.title('Iris Dataset Clusters')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.grid(True)

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, marker='*', label='Centers')
plt.legend()
plt.show()

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Cluster
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 145        2
# 146        0
# 147        2
# 148        2
# 149        0
#
# [150 rows x 5 columns]

# %% [markdown]
# #**Well done :)**
