# %% [markdown]
# <a href="https://colab.research.google.com/github/7atemAlawwad/T5/blob/main/RigEx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install beautifulsoup4

# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
xcite_URL = ('https://www.xcite.com/ar-KW')

aliexpress_response = requests.get(xcite)
aliexpress_soup = BeautifulSoup(xcite_response.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-3b498778360b> in <cell line: 3>()
#       1 xcite_URL = ('https://www.xcite.com/ar-KW')
#       2
# ----> 3 aliexpress_response = requests.get(xcite)
#       4 aliexpress_soup = BeautifulSoup(xcite_response.text, 'html.parser')
#
# NameError: name 'xcite' is not defined

# %%
xcite_response

# %%
xcite_response.status_code
# Out:
# 200

# %%
xcite_response.text
# Out:
# '<!DOCTYPE html><html lang="ar-KW" dir="rtl"><head><meta charSet="UTF-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><meta http-equiv="X-UA-Compatible" content="ie=edge"/><meta name="robots" content="index, follow"/><link rel="alternate" hrefLang="ar-KW" href="https://www.xcite.com/ar-KW"/><link rel="alternate" hrefLang="en-KW" href="https://www.xcite.com"/><link rel="alternate" hrefLang="x-default" href="https://www.xcite.com/ar-KW"/><link rel="canonical" href="https://www.xcite.com/ar-KW"/><title>اكسايت الغانم: أكبر متجر لشراء الكترونيات أونلاين في الكويت</title><meta name="description" content="اكسايت الغانم - وجهة التسوق الرائدة عبر الإنترنت في الكويت. اكتشف مجموعة متنوعة من الأجهزة الإلكترونية. تسوق أونلاين في الكويت الآن للحصول على أفضل العروض مع توصيل م"/><script type="application/ld+json">{\n              "@context": "https://schema.org/",\n              "@type": "ElectronicsStore",\n              "brand": {\n                "@type": "Thing",\n    
# ...

# %%
xcite_soup.title
# Out:
# <title>اكسايت الغانم: أكبر متجر لشراء الكترونيات أونلاين في الكويت</title>

# %%
xcite_soup.title.string
# Out:
# 'اكسايت الغانم: أكبر متجر لشراء الكترونيات أونلاين في الكويت'

# %%
first_product = aliexpress_soup.find('div' ,{'class': 'ProductTile_wrapper__XPYR3'})
print(first_product.prettify())
# Out:
# <div class="ProductTile_wrapper__XPYR3" data-insights-filter="ونسا جولد:214.9" data-insights-object-id="545229">
#  <div class="text-center">
#   <span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%">
#    <span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%">
#     <img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27500%27%20height=%27500%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/>
#    </span>
# ...

# %%
print(first_product.prettify())
# Out:
# <div class="ProductTile_wrapper__XPYR3" data-insights-filter="ونسا جولد:214.9" data-insights-object-id="545229">
#  <div class="text-center">
#   <span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%">
#    <span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%">
#     <img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27500%27%20height=%27500%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/>
#    </span>
# ...

# %%
first_product.find('div', class_='text-center')
# Out:
# <div class="text-center"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27500%27%20height=%27500%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="مكيف سبليت جولد من ونسا، 23200وحدة حرارية بريطانية، اتصال واي فاي، WSUC23CAXGS-24 - أبيض" class="mb-4" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-heigh
# ...

# %%
first_product.find('div', class_='text-center').text
# Out:
# 'ونسا جولدمكيف سبليت جولد من ونسا، 23200وحدة حرارية بريطانية، اتصال واي فاي، WSUC23CAXGS-24 - أبيض214.900 د.ك.425.000 د.ك. 49%'

# %%
first_product.find('div', class_='text-center').text.strip()
# Out:
# 'ونسا جولدمكيف سبليت جولد من ونسا، 23200وحدة حرارية بريطانية، اتصال واي فاي، WSUC23CAXGS-24 - أبيض214.900 د.ك.425.000 د.ك. 49%'

# %%
first_product.find('span', class_='text-2xl text-functional-red-800 block mb-2').text
# Out:
# '214.900 د.ك.'
